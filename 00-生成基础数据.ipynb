# %%
import os
os.makedirs('data',exist_ok=True)
data_content="""1号线,120000
2号线,150000
3号线,90000
"""
with open('data/ridership.txt','w',encoding='utf-8')as f:
    f.write(data_content)
print("ridership.txt 创建成功！")
# Out:
# ridership.txt 创建成功！
