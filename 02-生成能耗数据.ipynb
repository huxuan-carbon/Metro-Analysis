# %%
import os
os.makedirs('data',exist_ok=True)
energy_content="""1号线,50000,250000
2号线,60000,310000
3号线,45000,220000
"""
with open('data/energy.csv','w',encoding='utf-8') as f:
    f.write(energy_content)
print("energy.csv创建成功！")
# Out:
# energy.csv创建成功！
