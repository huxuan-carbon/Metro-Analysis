# %%
try:
    result=100/0
except ZeroDivisionError as e:
    print(f"除零错误：{e}")
except Exception as e:
    print(f"未知错误:{e}")
finally:
    print("无论对错，这句话都打印")
# Out:
# 除零错误：division by zero
# 无论对错，这句话都打印
